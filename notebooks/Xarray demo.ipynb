# %%
# %matplotlib inline
from cablab import Cube
from cablab import CubeData
from cablab.cube_access import CubeDataAccess
from datetime import datetime
import matplotlib as plt

# %%
cube = Cube.open("/Users/fgans/scratch/datacube2/")
cube_reader = CubeDataAccess(cube)
# Out:
# WARNING: outdated cube model version, current version is 0.2

# %%
cube_reader.variable_names
# Out:
# ['air_temperature_2m', 'precipitation']

# %%
ds=cube_reader.dataset('air_temperature_2m')

# %%
ds['air_temperature_2m'][:,95,95].plot()

# %%
fr=(ds['air_temperature_2m']<273.15).groupby('time.month').mean('time')

# %%
fr[:,100,100].plot()
# Out:
# /Users/fgans/anaconda/envs/cablab/lib/python3.5/site-packages/dask/array/core.py:2087: RuntimeWarning: invalid value encountered in less
#   return function(*args2, **kwargs)

# %%
fr[1,:,:].plot()
# Out:
# /Users/fgans/anaconda/envs/cablab/lib/python3.5/site-packages/dask/array/core.py:2087: RuntimeWarning: invalid value encountered in less
#   return function(*args2, **kwargs)
